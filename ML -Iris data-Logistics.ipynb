# %%
import numpy as np
import pandas as pd
from sklearn import linear_model 
import matplotlib.pyplot as plt
#%matplotlib.inline

# %%
a=pd.read_csv('iris.csv')
a
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
a.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# petal.length    150 non-null float64
# petal.width     150 non-null float64
# variety         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
print(a.max(),a.min(),a.var(),a.std(),a.mean(),a.median())
# Out:
# sepal.length          7.9
# sepal.width           4.4
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object sepal.length       4.3
# sepal.width          2
# petal.length         1
# petal.width        0.1
# variety         Setosa
# dtype: object sepal.length    0.685694
# sepal.width     0.189979
# petal.length    3.116278
# petal.width     0.581006
# dtype: float64 sepal.length    0.828066
# sepal.width     0.435866
# petal.length    1.765298
# petal.width     0.762238
# dtype: float64 sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64 sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64

# %%
a.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
a.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
#b=pd.DataFrame(a)
#b

# %%
#type(b)

# %%
#r=b.rename(index=str, columns={"5.1": "Sepal_width", "3.5": "Sepal_length","1.4":"Petal_width","0.2":"Petal_length"})

# %%
#r.head()

# %%
#r.ffill()

# %%
#import matplotlib.pyplot as plt
#plt.scatter

# %%
a.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(a[['sepal.length']],a.variety,train_size=0.9)

# %%
X_test
# Out:
#      sepal.length
# 7             5.0
# 105           7.6
# 114           5.8
# 111           6.4
# 81            5.5
# 50            7.0
# 65            6.7
# 63            6.1
# 108           6.7
# 125           7.2
# 0             5.1
# 24            4.8
# 117           7.7
# 38            4.4
# 53            5.5

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_test
# Out:
#      sepal.length
# 7             5.0
# 105           7.6
# 114           5.8
# 111           6.4
# 81            5.5
# 50            7.0
# 65            6.7
# 63            6.1
# 108           6.7
# 125           7.2
# 0             5.1
# 24            4.8
# 117           7.7
# 38            4.4
# 53            5.5

# %%
y_predicted=model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.42962087, 0.3232541 , 0.24712503],
#        [0.08964709, 0.33862638, 0.57172653],
#        [0.30364419, 0.34438933, 0.35196649],
#        [0.214604  , 0.35092958, 0.43446642],
#        [0.35128507, 0.33776346, 0.31095147],
#        [0.14209336, 0.34819696, 0.50970968],
#        [0.17588674, 0.35062728, 0.47348597],
#        [0.25757468, 0.34885696, 0.39356836],
#        [0.17588674, 0.35062728, 0.47348597],
#        [0.12241107, 0.34558897, 0.53199996],
#        [0.41433767, 0.32639718, 0.25926515],
#        [0.45925584, 0.31677496, 0.2239692 ],
#        [0.08274207, 0.33662417, 0.58063376],
#        [0.51376769, 0.30367387, 0.18255845],
#        [0.35128507, 0.33776346, 0.31095147]])

# %%
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
X_test
# Out:
#      sepal.length
# 7             5.0
# 105           7.6
# 114           5.8
# 111           6.4
# 81            5.5
# 50            7.0
# 65            6.7
# 63            6.1
# 108           6.7
# 125           7.2
# 0             5.1
# 24            4.8
# 117           7.7
# 38            4.4
# 53            5.5

# %%
model.predict(X_test)
# Out:
# array(['Setosa', 'Virginica', 'Virginica', 'Virginica', 'Setosa',
#        'Virginica', 'Virginica', 'Virginica', 'Virginica', 'Virginica',
#        'Setosa', 'Setosa', 'Virginica', 'Setosa', 'Setosa'], dtype=object)

# %% [markdown]
# # Multiple LOgistic regression

# %%
from sklearn import datasets

# %%
Data= datasets.load_iris()

# %%
s=Data.data[0]

# %%
Data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
Data.DESCR
# Out:
# '.. _iris_dataset:\n\nIris plants dataset\n--------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 150 (50 in each of three classes)\n    :Number of Attributes: 4 numeric, predictive attributes and the class\n    :Attribute Information:\n        - sepal length in cm\n        - sepal width in cm\n        - petal length in cm\n        - petal width in cm\n        - class:\n                - Iris-Setosa\n                - Iris-Versicolour\n                - Iris-Virginica\n                \n    :Summary Statistics:\n\n    ============== ==== ==== ======= ===== ====================\n                    Min  Max   Mean    SD   Class Correlation\n    ============== ==== ==== ======= ===== ====================\n    sepal length:   4.3  7.9   5.84   0.83    0.7826\n    sepal width:    2.0  4.4   3.05   0.43   -0.4194\n    petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\n    petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)\n    ============== ====
# ...

# %%
Data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(a[s],a.variety,train_size=0.9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-ba139a544047> in <module>
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(a[s],a.variety,train_size=0.9)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
X_test
# Out:
#      sepal.length
# 69            5.6
# 146           6.3
# 113           5.7
# 130           7.4
# 84            5.4
# 43            5.0
# 75            6.6
# 11            4.8
# 61            5.9
# 13            4.3
# 1             4.9
# 98            5.1
# 115           6.4
# 21            5.1
# 18            5.7

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_test
# Out:
#      sepal.length
# 71            6.1
# 50            7.0
# 141           6.9
# 36            5.5
# 82            5.8
# 67            5.8
# 15            5.7
# 22            4.6
# 133           6.3
# 75            6.6
# 70            5.9
# 12            4.8
# 145           6.7
# 27            5.2
# 98            5.1

# %%
y_predicted=model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-106-c8a642a703eb> in <module>
# ----> 1 y_predicted=model.predict(X_test)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     261         if not hasattr(self, 'coef_') or self.coef_ is None:
#     262             raise NotFittedError("This %(name)s instance is not fitted "
# --> 263                                  "yet" % {'name': type(self).__name__})
#     264
# ...

# %%
model.predict_proba(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-107-d905ae859022> in <module>
# ----> 1 model.predict_proba(X_test)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py in predict_proba(self, X)
#    1646         """
#    1647         if not hasattr(self, "coef_"):
# -> 1648             raise NotFittedError("Call fit before prediction")
#    1649
#    1650         ovr = (self.multi_class in ["ovr", "warn"] or
#
# NotFittedError: Call fit before prediction

# %%
model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-108-d3b3987fd8a5> in <module>
# ----> 1 model.score(X_test,y_test)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     355         """
#     356         from .metrics import accuracy_score
# --> 357         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     358
#     359
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ...

# %%
model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-109-decd67bbf386> in <module>
# ----> 1 model.predict(X_test)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     261         if not hasattr(self, 'coef_') or self.coef_ is None:
#     262             raise NotFittedError("This %(name)s instance is not fitted "
# --> 263                                  "yet" % {'name': type(self).__name__})
#     264
# ...
